# %%
from pynsee.macrodata.get_series_list import get_series_list
from pynsee.macrodata.get_series import get_series
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from datetime import datetime

# %%
raw_data = pd.read_excel('Data/prc_hicp_midx_page_spreadsheet.xlsx', sheet_name = "Sheet 1", skiprows = 8)
# Filter and keep only columns that do not start with "Unnamed"
df = raw_data.loc[:, ~raw_data.columns.str.startswith('Unnamed')]
df = df.iloc[1:-5]
# Out:
# /opt/mamba/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df = df[~df.iloc[:, 0].str.startswith("Euro")]

# %%
df.replace(":", np.nan, inplace=True)

# %%
print(df)
# Out:
#                TIME  1996-01  1996-02  1996-03  1996-04  1996-05  1996-06  \
# 7           Belgium    69.91    69.98    70.12    70.47    70.61    70.47
# 8          Bulgaria      NaN      NaN      NaN      NaN      NaN      NaN
# 9           Czechia    57.00    57.30    57.60    58.10    58.40    58.90
# 10          Denmark    70.40    70.80    71.30    71.50    71.70    71.60
# 11          Germany    75.10    75.60    75.70    75.60    75.70    75.80
# 12          Estonia    42.87    44.24    44.95    45.72    45.95    46.23
# 13          Ireland    68.10    68.60    68.90    68.80    68.90    69.10
# 14           Greece    59.04    58.92    60.64    61.25    61.74    61.86
# 15            Spain    63.95    64.08    64.34    64.73    64.99    64.93
# 16           France    74.13    74.42    74.90    74.99    75.19    75.11
# 17          Croatia      NaN      NaN      NaN      NaN      NaN      NaN
# 18            Italy    67.50    67.80    68.00    68.30    68.50    68.70
# ...
